# %%
import math
import re
import os

jobs_per_task = 10

log_dir = "logs"

for fname in os.listdir(log_dir):

    if not fname.startswith("err_17766662_"):
        continue

    path = os.path.join(log_dir, fname)

    if os.path.getsize(path) == 0:
        continue

    task_id = int(re.search(r'_(\d+)\.txt$', fname).group(1))

    start = (task_id - 1) * jobs_per_task + 1
    end = start + jobs_per_task - 1

    print(f"{fname}: jobs.txt lines {start}-{end}")
# Out:
# err_17766662_77.txt: jobs.txt lines 761-770
# err_17766662_85.txt: jobs.txt lines 841-850
# err_17766662_39.txt: jobs.txt lines 381-390
# err_17766662_37.txt: jobs.txt lines 361-370
# err_17766662_60.txt: jobs.txt lines 591-600
# err_17766662_143.txt: jobs.txt lines 1421-1430
# err_17766662_130.txt: jobs.txt lines 1291-1300
# err_17766662_42.txt: jobs.txt lines 411-420
# err_17766662_55.txt: jobs.txt lines 541-550
# err_17766662_111.txt: jobs.txt lines 1101-1110
# err_17766662_36.txt: jobs.txt lines 351-360

# %% [markdown]
# 36*
# +234|191224|Rat_234_Lev4_GNG1Stim_191224.mat|Events_TN234_191224_ekg_behavior_Level4.nev|CSC127_TN234_191224_ekg_behavior_Level4.ncs
# 234|201224|Rat_234_Staircase_201224.mat|Events_TN234_201224_ekg_behavior_Staircase.nev|CSC127_TN234_201224_ekg_behavior_Staircase.ncs
# +234|261224|Rat_234_Staircase_261224.mat|Events_TN234_261224_ekg_behavior_Staircase.nev|CSC127_TN234_261224_ekg_behavior_Staircase.ncs
# 234|271224|Rat_234_Staircase_271224.mat|Events_TN234_271224_ekg_behavior_Staircase.nev|CSC127_TN234_271224_ekg_behavior_Staircase.ncs
# +234|281224|Rat_234_Lev6_GNG_HardNogo_281224.mat|Events_TN234_281224_ekg_behavior_HardNoGo.nev|CSC127_TN234_281224_ekg_behavior_HardNoGo.ncs
# +235|050125|Rat_235_Lev6_GNG_HardNogo_050125.mat|Events_TN235_050125_ekg_behavior_HardNoGo.nev|CSC127_TN235_050125_ekg_behavior_HardNoGo.ncs
# +235|121224|Rat_235_Lev4_GNG1Stim_121224.mat|Events_TN235_121224_ekg_behavior_Level4.nev|CSC127_TN235_121224_ekg_behavior_Level4.ncs
# +235|131224|Rat_235_Lev4_GNG1Stim_131224.mat|Events_TN235_131224_ekg_behavior_Level4.nev|CSC127_TN235_131224_ekg_behavior_Level4.ncs
#
# 37
# dataAnalyst('291', '010620', '/scratch/work/bahriz1/tmp/tmp9j2iou74', 'Rat 291 Lev5_Visual_GNG_8020 01-Jun-2020.mat', 'Events_291_010620.nev', 'CSC95_291_010620.ncs')"]
#
# 39
# dataAnalyst('291', '170620', '/scratch/work/bahriz1/tmp/tmp_13l3nwb', 'Rat 291 Lev5_Visual_GNG_8020 17-Jun-2020.mat', 'Events_291_170620.nev', 'CSC95_291_170620.ncs')"]
#
# 42
# dataAnalyst('293', '290520', '/scratch/work/bahriz1/tmp/tmph0s5fb98', 'Rat 293 Staircase 29-May-2020.mat', 'Events_293_290520.nev', 'CSC95_293_290520.ncs')"]
#
#
# 55*
# 531|020720|Rat 531 Lev6_IDS 02-Jul-2020 .mat|Events_531_020720.nev|CSC95_531_020720.ncs
# 531|030720|Rat 531 Lev5_GNG2Stim 03-Jul-2020.mat|Events_531_030720.nev|CSC95_531_030720.ncs
#
#
# 85
# dataAnalyst('561', '130820', '/scratch/work/bahriz1/tmp/tmppdbtjzc4', 'Rat 561 Lev5_Visual_GNG_8020 13-Aug-2020.mat', 'Events_561_130820.nev', 'CSC95_561_130820.ncs')"]
#
# 130
# dataAnalyst('8582', '051018', '/scratch/work/bahriz1/tmp/tmpwmyet4vk', 'Rat 8582 Lev5_GNG2Stim 05-Oct-2018.mat', 'Events_8582_051018.nev', 'CSC95_8582_051018.ncs')"]
#
# dataAnalyst('8582', '121018', '/scratch/work/bahriz1/tmp/tmpxeasdrfh', 'Rat 8582 Lev6_AttnPsychophysDiscrim 12-Oct-2018.mat', 'Events_8582_121018.nev', 'CSC95_8582_121018.ncs')"]
#
#
# 143*
# +9591|210519|Rat 9591 Lev5_GNG2Stim 21-May-2019.mat|Events_9591_210519.nev|CSC95_9591_210519.ncs
# 9591|220519|Rat 9591 Lev6_EDS 22-May-2019 .mat|Events_9591_220519.nev|CSC95_9591_220519.ncs
# +9591|230519|Rat 9591 Lev5_GNG2Stim 23-May-2019.mat|Events_9591_230519.nev|CSC95_9591_230519.ncs
# +9591|240419|Rat 9591 Lev5_GNG2Stim 24-Apr-2019.mat|Events_9591_240419.nev|CSC95_9591_240419.ncs
# +9591|240519|Rat 9591 Lev5_GNG2Stim 24-May-2019.mat|Events_9591_240519.nev|CSC95_9591_240519.ncs
# +9591|250419|Rat 9591 Lev5_GNG2Stim 25-Apr-2019.mat|Events_9591_250419.nev|CSC95_9591_250419.ncs

# %% [markdown]
# ### Files that time out
#
# 234|201224|Rat_234_Staircase_201224.mat|Events_TN234_201224_ekg_behavior_Staircase.nev|CSC127_TN234_201224_ekg_behavior_Staircase.ncs
#
# 234|271224|Rat_234_Staircase_271224.mat|Events_TN234_271224_ekg_behavior_Staircase.nev|CSC127_TN234_271224_ekg_behavior_Staircase.ncs
#
# 531|020720|Rat 531 Lev6_IDS 02-Jul-2020 .mat|Events_531_020720.nev|CSC95_531_020720.ncs
#
# 531|030720|Rat 531 Lev5_GNG2Stim 03-Jul-2020.mat|Events_531_030720.nev|CSC95_531_030720.ncs
#
# 9591|220519|Rat 9591 Lev6_EDS 22-May-2019 .mat|Events_9591_220519.nev|CSC95_9591_220519.ncs

# %% [markdown]
# ### Files in which IntruResp = Number of HIT and FA trials - 1
#
# 291|010620|Rat 291 Lev5_Visual_GNG_8020 01-Jun-2020.mat|Events_291_010620.nev|CSC95_291_010620.ncs
#
# 291|170620|Rat 291 Lev5_Visual_GNG_8020 17-Jun-2020.mat|Events_291_170620.nev|CSC95_291_170620.ncs
#
# 293|290520|Rat 293 Staircase 29-May-2020.mat|Events_293_290520.nev|CSC95_293_290520.ncs
#
# 561|130820|Rat 561 Lev5_Visual_GNG_8020 13-Aug-2020.mat|Events_561_130820.nev|CSC95_561_130820.ncs
#
# 8582|051018|Rat 8582 Lev5_GNG2Stim 05-Oct-2018.mat|Events_8582_051018.nev|CSC95_8582_051018.ncs
#
# 8582|121018|Rat 8582 Lev6_AttnPsychophysDiscrim 12-Oct-2018.mat|Events_8582_121018.nev|CSC95_8582_121018.ncs
